# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('../data/processed/df_with_anomalies.csv', parse_dates=['timestamp'])
df.set_index('timestamp', inplace=True)
df.head()
# Out:
#               btc_price    btc_volume   eth_price    eth_volume  fees  \
# timestamp
# 2018-08-18  6566.715163  6.206194e+09  314.793253  2.930410e+09   8.0
# 2018-08-19  6382.060591  5.616966e+09  293.176992  2.806352e+09  26.0
# 2018-08-20  6475.494020  5.160365e+09  299.435123  2.503897e+09   8.0
# 2018-08-21  6242.882438  5.578292e+09  271.061552  2.209797e+09  35.0
# 2018-08-22  6467.271730  5.658517e+09  280.374717  2.099628e+09  42.0
#
#             stablecoins_supply  defi_tvl    market_cap        volume  \
# timestamp
# 2018-08-18          15127992.0  367401.0  2.295305e+11  1.806076e+10
# 2018-08-19          15127992.0  365249.0  2.152358e+11  1.523521e+10
# 2018-08-20          15127992.0  363340.0  2.216411e+11  1.379505e+10
# 2018-08-21          15127992.0  358941.0  2.092269e+11  1.344527e+10
# 2018-08-22          15127992.0  316470.0  2.151441e+11  1.239502e+10
#
#             fng_value  is_panic_day  is_defi_stress_day  panic_in_next_days  \
# timestamp
# 2018-08-18         24             0                   0                 0.0
# 2018-08-19         27             0                   0                 0.0
# 2018-08-20         26             0                   0                 0.0
# 2018-08-21         19             1                   0                 0.0
# 2018-08-22         21             0                   0                 0.0
#
#             is_pure_stress_day  target
# timestamp
# 2018-08-18                   0     0.0
# 2018-08-19                   0     0.0
# 2018-08-20                   0     0.0
# 2018-08-21                   0     0.0
# 2018-08-22                   0     0.0

# %%
df.sort_index(inplace=True)

def get_approx_btc_supply(date):
    halving_2_date = pd.to_datetime('2016-07-09')
    supply_at_h2 = 15750000

    halving_3_date = pd.to_datetime('2020-05-11')
    supply_at_h3 = 18375000

    halving_4_date = pd.to_datetime('2024-04-20')
    supply_at_h4 = 19687500

    reward_era_2 = 25.0
    reward_era_3 = 12.5
    reward_era_4 = 6.25
    reward_era_5 = 3.125

    blocks_per_day = 144

    date = pd.to_datetime(date).normalize()
    if date < halving_2_date:
        return 15000000
    elif date < halving_3_date:
        days_since_h2 = (date - halving_2_date).days
        return supply_at_h2 + (days_since_h2 * blocks_per_day * reward_era_3)
    elif date < halving_4_date:
        days_since_h3 = (date - halving_3_date).days
        return supply_at_h3 + (days_since_h3 * blocks_per_day * reward_era_4)
    else:
        days_since_h4 = (date - halving_4_date).days
        return supply_at_h4 + (days_since_h4 * blocks_per_day * reward_era_5)

df['btc_circulating_supply'] = df.index.to_series().apply(get_approx_btc_supply)

# %%
# Tech features
df['btc_return_1d'] = df['btc_price'].pct_change(1)
df['eth_return_1d'] = df['eth_price'].pct_change(1)

for lag in [1, 3, 7]:
    df[f'btc_return_{lag}d'] = df['btc_return_1d'].shift(lag)
    df[f'eth_return_{lag}d'] = df['eth_return_1d'].shift(lag)

df['btc_volatility_7d'] = df['btc_return_1d'].rolling(window=7).std()
df['eth_volatility_7d'] = df['eth_return_1d'].rolling(window=7).std()
df['btc_volatility_30d'] = df['btc_return_1d'].rolling(window=30).std()
df['eth_volatility_30d'] = df['eth_return_1d'].rolling(window=30).std()

btc_ma_short = df['btc_price'].rolling(window=7).mean()
btc_ma_long = df['btc_price'].rolling(window=30).mean()
df['btc_price_momentum_signal'] = btc_ma_short/ btc_ma_long

eth_ma_short = df['eth_price'].rolling(window=7).mean()
eth_ma_long = df['eth_price'].rolling(window=30).mean()
df['eth_price_momentum_signal'] = eth_ma_short / eth_ma_long

df['volume_change_1d'] = df['volume'].pct_change(1)
df['volume_change_7d'] = df['volume'].pct_change(7)
volume_momentum_signal = df['volume'].rolling(7).mean() / df['volume'].rolling(30).mean()
df['volume_spike_signal'] = df['volume'] / df['volume'].rolling(30).mean()

df['btc_volume_change_1d'] = df['btc_volume'].pct_change(1)
df['btc_volume_change_7d'] = df['btc_volume'].pct_change(7)
df['eth_volume_change_1d'] = df['eth_volume'].pct_change(1)
df['eth_volume_change_7d'] = df['eth_volume'].pct_change(7)
df['btc_volume_momentum_signal'] = df['btc_volume'].rolling(7).mean() / df['btc_volume'].rolling(30).mean()
df['eth_volume_momentum_signal'] = df['eth_volume'].rolling(7).mean() / df['eth_volume'].rolling(30).mean()

df['tvl_change_1d'] = df['defi_tvl'].pct_change(1)
df['tvl_change_7d'] = df['defi_tvl'].pct_change(7)
df['tvl_change_30d'] = df['defi_tvl'].pct_change(30)
df['tvl_momentum_signal'] = df['defi_tvl'].rolling(30).mean() / df['defi_tvl'].rolling(90).mean()

df['fees_ma_7d'] = df['fees'].rolling(window=7).mean()
df['fees_spike_signal'] = df['fees'] / df['fees'].rolling(30).mean()

df['MarketConcentration_Proxy'] = (df['btc_price'] * df['btc_circulating_supply']) / df['market_cap']
df['ETH_Volatility_30d'] = df['eth_return_1d'].rolling(window=30).std()
df['LiquidationPressureIndex'] = df['ETH_Volatility_30d'] * (100 - df['fng_value'])
df['SentimentMomentum_7d'] = df['fng_value'].diff(7)
df['Capital_Efficiency'] = df['volume'] / df['defi_tvl']

# %%
df.dropna(inplace=True)
df.head()
# Out:
#               btc_price    btc_volume   eth_price    eth_volume  fees  \
# timestamp
# 2018-11-15  5788.612494  5.690410e+09  184.022559  2.658769e+09  44.0
# 2018-11-16  5686.541131  4.981979e+09  182.448243  2.461870e+09  23.0
# 2018-11-17  5609.956182  3.236633e+09  176.022406  1.724797e+09  20.0
# 2018-11-18  5599.191596  2.525819e+09  175.667416  1.412768e+09  86.0
# 2018-11-19  5638.861481  2.422604e+09  177.728690  1.419370e+09  35.0
#
#             stablecoins_supply    defi_tvl    market_cap        volume  \
# timestamp
# 2018-11-15          25140229.0   3683607.0  1.941663e+11  2.012710e+10
# 2018-11-16          25140229.0   3916651.0  1.912725e+11  1.678363e+10
# 2018-11-17          25140229.0   3777996.0  1.865874e+11  1.158796e+10
# 2018-11-18          25140229.0   3619614.0  1.878092e+11  1.114842e+10
# 2018-11-19          25140229.0  14168001.0  1.880922e+11  9.776134e+09
#
#             fng_value  ...  tvl_change_7d  tvl_change_30d  \
# timestamp              ...
# 2018-11-15         28  ...      -0.161401       -0.237979
# 2018-11-16         23  ...      -0.066622       -0.038763
# 2018-11-17         24  ...      -0.065863       -0.339936
# 2018-11-18         26  ...      -0.132657       -0.335361
# 2018-11-19         28  ...       2.469982        1.485601
#
#             tvl_momentum_signal  fees_ma_7d  fees_spike_signal  \
# timestamp
# 2018-11-15             1.649111   55.000000           1.264368
# 2018-11-16             1.625543   43.428571           0.666667
# 2018-11-17             1.583668   39.285714           0.626305
# 2018-11-18             1.545010   45.142857           2.629969
# 2018-11-19             1.559092   38.000000           1.059536
#
#             MarketConcentration_Proxy  ETH_Volatility_30d  \
# timestamp
# 2018-11-15                   0.515646            0.022709
# 2018-11-16                   0.514270            0.027453
# 2018-11-17                   0.520138            0.027444
# 2018-11-18                   0.515816            0.028005
# 2018-11-19                   0.518743            0.027560
#
#             LiquidationPressureIndex  SentimentMomentum_7d  Capital_Efficiency
# timestamp
# 2018-11-15                  1.635012                 -23.0         5463.964713
# 2018-11-16                  2.113909                 -24.0         4285.198059
# 2018-11-17                  2.085708                 -28.0         3067.223328
# 2018-11-18                  2.072335                 -28.0         3080.001423
# 2018-11-19                  1.984351                 -24.0          690.015062
#
# [5 rows x 48 columns]

# %%
df.to_csv('../data/processed/big_data_for_learning.csv', index=False)
